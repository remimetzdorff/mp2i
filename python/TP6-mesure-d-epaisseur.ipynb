# %%
# %pylab inline

def mysavefig(filename):
    plt.tight_layout()
    plt.savefig("../images/tp6/"+filename, bbox_inches="tight", dpi=200)
    return
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
e = 1e-6
x = np.linspace(-e/5,e/5,1001)

plt.plot(x, 2/(e+x) + 1/(e-x))
plt.plot(x, 1/e * (3 - (x/e) + 3*(x/e)**2))
