# %%
# %pylab inline
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
r = np.array([1, 10, 100, 1000, 1e4, 1e5])
i = np.array([489, 485, 446, 247, 45, 4.95, .5]) #uA
u = np.array([487, 498, 498, 498, 499, 499, 498]) #mV

plt.plot(u,i, "o")

# %%
r = 1e3
i = np.array([262, 242, 226, 212, 194, 168, 104, 57, 15]) #uA
u = np.array([530, 488, 456, 429, 390, 338, 210, 115, 30]) #mV

plt.plot(u,i, "o")

# %%
r = np.array([1,   2,  3,  5,  10,  20,  30,  40,  50,  60,  80, 100, 200, 500])
u = np.array([20, 39, 61, 96, 188, 338, 406, 431, 442, 450, 457, 461, 470, 473])*1e-3
i = u/r
plt.plot(i,i*u, "o")

# %%
plt.plot(u,i, "o")
